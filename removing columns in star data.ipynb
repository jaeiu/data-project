# %%
import pandas as pd

#Load the dataset for 0-star players
df_0Star = pd.read_csv("C:\\Users\\fredd\\Documents\\star data\\data_0 Star.csv")

#Drop the 'submitted_date' and 'player_id' columns as they are not needed for analysis
df_0Star.drop(columns=['submitted_date', 'player_id'], inplace=True)
df_0Star.drop(df_0Star.index[100::], inplace=True)


df_0Star.head(100)
# Out:
#     Unnamed: 0        id  place                              speedrun_link  \
# 0            0  zp56lrry      1  http://www.speedrun.com/sm64/run/zp56lrry
# 1            1  m3vr6ggz      2  http://www.speedrun.com/sm64/run/m3vr6ggz
# 2            2  yo5x381z      3  http://www.speedrun.com/sm64/run/yo5x381z
# 3            3  z00x1qoz      4  http://www.speedrun.com/sm64/run/z00x1qoz
# 4            4  ydl4l90z      5  http://www.speedrun.com/sm64/run/ydl4l90z
# ..         ...       ...    ...                                        ...
# 95          95  z5g38onm     93  http://www.speedrun.com/sm64/run/z5g38onm
# 96          96  y4nk11nm     93  http://www.speedrun.com/sm64/run/y4nk11nm
# 97          97  0y6gv1m7     98  http://www.speedrun.com/sm64/run/0y6gv1m7
# 98          98  y9668wey     99  http://www.speedrun.com/sm64/run/y9668wey
# 99          99  y6jjne6m     99  http://www.speedrun.com/sm64/run/y6jjne6m
#
# ...

# %%
#Load the dataset for 1-star players
df_16Star = pd.read_csv("C:\\Users\\fredd\\Documents\\star data\\data_16 star.csv")

#Drop the 'submitted_date' and 'player_id' columns as they are not needed for analysis
df_16Star.drop(columns=['submitted_date', 'player_id'], inplace=True)
df_16Star.drop(df_16Star.index[100::], inplace=True)


df_16Star.head(200)
# Out:
#     Unnamed: 0        id  place                              speedrun_link  \
# 0            0  yol5kxjy      1  http://www.speedrun.com/sm64/run/yol5kxjy
# 1            1  zng5delm      2  http://www.speedrun.com/sm64/run/zng5delm
# 2            2  zppddvxz      3  http://www.speedrun.com/sm64/run/zppddvxz
# 3            3  yoeq9vjz      4  http://www.speedrun.com/sm64/run/yoeq9vjz
# 4            4  y60jnn0y      5  http://www.speedrun.com/sm64/run/y60jnn0y
# ..         ...       ...    ...                                        ...
# 95          95  zpok558m     96  http://www.speedrun.com/sm64/run/zpok558m
# 96          96  z5w4exnz     96  http://www.speedrun.com/sm64/run/z5w4exnz
# 97          97  y25dx8jy     98  http://www.speedrun.com/sm64/run/y25dx8jy
# 98          98  y6vl5p0m     99  http://www.speedrun.com/sm64/run/y6vl5p0m
# 99          99  z07xvv9y    100  http://www.speedrun.com/sm64/run/z07xvv9y
#
# ...

# %%
#Load the dataset for 1-star players
df_1Star = pd.read_csv("C:\\Users\\fredd\\Documents\\star data\\data_1 star.csv")

#Drop the 'submitted_date' and 'player_id' columns as they are not needed for analysis
df_1Star.drop(columns=['submitted_date', 'player_id'], inplace=True)
df_1Star.drop(df_1Star.index[100::], inplace=True)


df_1Star.head(200)
# Out:
#     Unnamed: 0        id  place                              speedrun_link  \
# 0            0  z0k8qe9m      1  http://www.speedrun.com/sm64/run/z0k8qe9m
# 1            1  me20pn8m      2  http://www.speedrun.com/sm64/run/me20pn8m
# 2            2  z0kpxvem      3  http://www.speedrun.com/sm64/run/z0kpxvem
# 3            3  z5lgrjgy      4  http://www.speedrun.com/sm64/run/z5lgrjgy
# 4            4  y6g3g5jm      5  http://www.speedrun.com/sm64/run/y6g3g5jm
# ..         ...       ...    ...                                        ...
# 95          95  0y6v4npm     96  http://www.speedrun.com/sm64/run/0y6v4npm
# 96          96  mreep52y     96  http://www.speedrun.com/sm64/run/mreep52y
# 97          97  ywx14d2m     96  http://www.speedrun.com/sm64/run/ywx14d2m
# 98          98  z566dxny     99  http://www.speedrun.com/sm64/run/z566dxny
# 99          99  y46n1x2z    100  http://www.speedrun.com/sm64/run/y46n1x2z
#
# ...

# %%
#Load the dataset for 1-star players
df_70Star = pd.read_csv("C:\\Users\\fredd\\Documents\\star data\\data_70 star.csv")

#Drop the 'submitted_date' and 'player_id' columns as they are not needed for analysis
df_70Star.drop(columns=['submitted_date', 'player_id'], inplace=True)
df_70Star.drop(df_70Star.index[100::], inplace=True)


df_70Star.head(100)
# Out:
#     Unnamed: 0        id  place                              speedrun_link  \
# 0            0  yoxwn51y      1  http://www.speedrun.com/sm64/run/yoxwn51y
# 1            1  zpo7ornm      2  http://www.speedrun.com/sm64/run/zpo7ornm
# 2            2  zqqn9jrz      3  http://www.speedrun.com/sm64/run/zqqn9jrz
# 3            3  zq2kgl5z      4  http://www.speedrun.com/sm64/run/zq2kgl5z
# 4            4  mew4438m      5  http://www.speedrun.com/sm64/run/mew4438m
# ..         ...       ...    ...                                        ...
# 95          95  jy9p82em     96  http://www.speedrun.com/sm64/run/jy9p82em
# 96          96  y6pok91m     96  http://www.speedrun.com/sm64/run/y6pok91m
# 97          97  z0lxd2oz     96  http://www.speedrun.com/sm64/run/z0lxd2oz
# 98          98  yo7n067m     99  http://www.speedrun.com/sm64/run/yo7n067m
# 99          99  yl7kk5xm     99  http://www.speedrun.com/sm64/run/yl7kk5xm
#
# ...

# %%
#Load the dataset for 1-star players
df_120Star = pd.read_csv("C:\\Users\\fredd\\Documents\\star data\\data_120 star.csv")

#Drop the 'submitted_date' and 'player_id' columns as they are not needed for analysis
df_120Star.drop(columns=['submitted_date', 'player_id'], inplace=True)
df_120Star.drop(df_120Star.index[100::], inplace=True)


df_120Star.head(200)
# Out:
#     Unnamed: 0        id  place                              speedrun_link  \
# 0            0  mk1x1wxy      1  http://www.speedrun.com/sm64/run/mk1x1wxy
# 1            1  z00v01jz      2  http://www.speedrun.com/sm64/run/z00v01jz
# 2            2  yv77ke4y      2  http://www.speedrun.com/sm64/run/yv77ke4y
# 3            3  yvx4o46z      4  http://www.speedrun.com/sm64/run/yvx4o46z
# 4            4  yv7jgrey      5  http://www.speedrun.com/sm64/run/yv7jgrey
# ..         ...       ...    ...                                        ...
# 95          95  z5dqn9em     96  http://www.speedrun.com/sm64/run/z5dqn9em
# 96          96  yvr5398z     97  http://www.speedrun.com/sm64/run/yvr5398z
# 97          97  m37g7q4z     98  http://www.speedrun.com/sm64/run/m37g7q4z
# 98          98  y4o941kz     99  http://www.speedrun.com/sm64/run/y4o941kz
# 99          99  ydj66ljy    100  http://www.speedrun.com/sm64/run/ydj66ljy
#
# ...

# %%
df_0Star.to_csv("C:\\Users\\fredd\\Downloads\\cleaner data\\data_0 star.csv", encoding='utf-8', index=False)
df_1Star.to_csv("C:\\Users\\fredd\\Downloads\\cleaner data\\data_1 star.csv", encoding='utf-8', index=False)
df_16Star.to_csv("C:\\Users\\fredd\\Downloads\\cleaner data\\data_16 star.csv", encoding='utf-8', index=False)
df_70Star.to_csv("C:\\Users\\fredd\\Downloads\\cleaner data\\data_70 star.csv", encoding='utf-8', index=False)
df_120Star.to_csv("C:\\Users\\fredd\\Downloads\\cleaner data\\data_120 star.csv", encoding='utf-8', index=False)
